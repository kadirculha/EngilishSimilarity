# %%
from config import Configurator
from sentence_transformer import SentenceTransformer
import pandas as pd

cfg = Configurator()

# %%
df = pd.DataFrame(cfg.data).T
df
# Out:
#                                             sentences
# 1   [I like to read books., Reading books is somet...
# 2   [She sings beautifully., Her singing is absolu...
# 3   [They love playing soccer., Playing soccer is ...
# 4   [He enjoys cooking new recipes., Cooking new r...
# 5   [My sister dances gracefully., Her graceful da...
# 6   [We often travel to new places., Exploring new...
# 7   [They speak multiple languages., Being multili...
# 8   [I swim in the ocean every summer., Swimming i...
# 9   [He runs marathons regularly., Running maratho...
# 10  [She paints beautiful landscapes., Creating be...
# 11  [We enjoy watching movies together., Watching ...
# 12  [They play musical instruments skillfully., Pl...
# 13  [I practice yoga every morning., Practicing yo...
# 14  [He writes insightful poems., Writing insightf...
# 15  [She codes computer programs effectively., Cod...
# 16  [They study diligently for their exams., Study...
# 17  [I enjoy hiking in the mountains., Hiking in t...
# 18  [He travels to different countries frequently....
# 19  [She creates amazing sculptures., Creating ama...
# 20  [We love exploring new cultures., Exploring ne...

# %%
type(df.sentences[0])
# Out:
# list

# %% [markdown]
# # all-MiniLM-L6-v2
# 2.5m download

# %%
l6_v2 = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
l6_v2_list = []
for index, sentence_list in df.iterrows():
    score = l6_v2.get_similarity(sentence_list[0])
    print(f"{index}. Cümle çifti:\n{sentence_list[0]}\nSimilarity Score:{score}\n")
    l6_v2_list.append(score)
# Out:
# 1. Cümle çifti:
# ['I like to read books.', 'Reading books is something I enjoy.']
# Similarity Score:0.8445432186126709
#
# 2. Cümle çifti:
# ['She sings beautifully.', 'Her singing is absolutely gorgeous.']
# Similarity Score:0.8478463888168335
#
# 3. Cümle çifti:
# ['They love playing soccer.', 'Playing soccer is their passion.']
# Similarity Score:0.8087419867515564
#
# 4. Cümle çifti:
# ['He enjoys cooking new recipes.', 'Cooking new recipes is his favorite hobby.']
# Similarity Score:0.8631986379623413
#
# 5. Cümle çifti:
# ['My sister dances gracefully.', 'Her graceful dance moves always mesmerize the audience.']
# Similarity Score:0.6408513188362122
#
# 6. Cümle çifti:
# ['We often travel to new places.', 'Exploring new places is something we do frequently.']
# Similarity Score:0.8034536242485046
#
# 7. Cümle çifti:
# ['They speak multiple languages.', 'Being multilingual is one of their impressive abilities.']
# Similarity Score:0.572630763053894
#
# 8. Cümle çifti:
# ['I swim in the ocean every summer.', 'Swimming in the ocean during the summer is a tradition for me.']
# Similarity Score:0.8038910031318665
#
# 9. Cümle çifti:
# ['He runs marathons regularly.', 'Running marathons is a part of his routine.']
# Similarity Score:0.871070384979248
#
# 10. Cümle çifti:
# ['She paints beautiful landscapes.', 'Creating beautiful landscapes through painting is her talent.']
# Similarity Score:0.8641557693481445
#
# 11. Cümle çifti:
# ['We enjoy watching movies together.', 'Watching movies together is our favorite bonding activity.']
# Similarity Score:0.8656816482543945
#
# 12. Cümle çifti:
# ['They play musical instruments skillfully.', 'Playing musical instruments skillfully is their forte.']
# Similarity Score:0.8431645035743713
#
# 13. Cümle çifti:
# ['I practice yoga every morning.', 'Practicing yoga is a daily ritual for me.']
# Similarity Score:0.8607196807861328
#
# 14. Cümle çifti:
# ['He writes insightful poems.', 'Writing insightful poems is his creative outlet.']
# Similarity Score:0.8989646434783936
#
# 15. Cümle çifti:
# ['She codes computer programs effectively.', 'Coding computer programs effectively is her expertise.']
# Similarity Score:0.8872023820877075
#
# 16. Cümle çifti:
# ['They study diligently for their exams.', 'Studying diligently for exams is their key to success.']
# Similarity Score:0.7636988162994385
#
# 17. Cümle çifti:
# ['I enjoy hiking in the mountains.', 'Hiking in the mountains is a thrilling experience for me.']
# Similarity Score:0.843566358089447
#
# 18. Cümle çifti:
# ['He travels to different countries frequently.', 'Frequent travel to different countries is a part of his job.']
# Similarity Score:0.8402215242385864
#
# 19. Cümle çifti:
# ['She creates amazing sculptures.', 'Creating amazing sculptures is her passion and profession.']
# Similarity Score:0.9053421020507812
#
# 20. Cümle çifti:
# ['We love exploring new cultures.', 'Exploring new cultures is a fascinating adventure for us.']
# Similarity Score:0.869345486164093

# %% [markdown]
# ## MPNET
# 500mb
#
# 9M download

# %%
mpnet_base_v2 = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')

# %%
mpnet_base_v2_list = []
for index, sentence_list in df.iterrows():
    score = mpnet_base_v2.get_similarity(sentence_list[0])
    print(f"{index}. Cümle çifti:\n{sentence_list[0]}\nSimilarity Score:{score}\n")
    mpnet_base_v2_list.append(score)
# Out:
# 1. Cümle çifti:
# ['I like to read books.', 'Reading books is something I enjoy.']
# Similarity Score:0.857397735118866
#
# 2. Cümle çifti:
# ['She sings beautifully.', 'Her singing is absolutely gorgeous.']
# Similarity Score:0.8866472840309143
#
# 3. Cümle çifti:
# ['They love playing soccer.', 'Playing soccer is their passion.']
# Similarity Score:0.8199930191040039
#
# 4. Cümle çifti:
# ['He enjoys cooking new recipes.', 'Cooking new recipes is his favorite hobby.']
# Similarity Score:0.9072308540344238
#
# 5. Cümle çifti:
# ['My sister dances gracefully.', 'Her graceful dance moves always mesmerize the audience.']
# Similarity Score:0.6157417297363281
#
# 6. Cümle çifti:
# ['We often travel to new places.', 'Exploring new places is something we do frequently.']
# Similarity Score:0.8297477960586548
#
# 7. Cümle çifti:
# ['They speak multiple languages.', 'Being multilingual is one of their impressive abilities.']
# Similarity Score:0.7492713928222656
#
# 8. Cümle çifti:
# ['I swim in the ocean every summer.', 'Swimming in the ocean during the summer is a tradition for me.']
# Similarity Score:0.7946268320083618
#
# 9. Cümle çifti:
# ['He runs marathons regularly.', 'Running marathons is a part of his routine.']
# Similarity Score:0.8912219405174255
#
# 10. Cümle çifti:
# ['She paints beautiful landscapes.', 'Creating beautiful landscapes through painting is her talent.']
# Similarity Score:0.8863568902015686
#
# 11. Cümle çifti:
# ['We enjoy watching movies together.', 'Watching movies together is our favorite bonding activity.']
# Similarity Score:0.8928654193878174
#
# 12. Cümle çifti:
# ['They play musical instruments skillfully.', 'Playing musical instruments skillfully is their forte.']
# Similarity Score:0.756610095500946
#
# 13. Cümle çifti:
# ['I practice yoga every morning.', 'Practicing yoga is a daily ritual for me.']
# Similarity Score:0.8434990048408508
#
# 14. Cümle çifti:
# ['He writes insightful poems.', 'Writing insightful poems is his creative outlet.']
# Similarity Score:0.8607963919639587
#
# 15. Cümle çifti:
# ['She codes computer programs effectively.', 'Coding computer programs effectively is her expertise.']
# Similarity Score:0.9074519872665405
#
# 16. Cümle çifti:
# ['They study diligently for their exams.', 'Studying diligently for exams is their key to success.']
# Similarity Score:0.8087142705917358
#
# 17. Cümle çifti:
# ['I enjoy hiking in the mountains.', 'Hiking in the mountains is a thrilling experience for me.']
# Similarity Score:0.8456312417984009
#
# 18. Cümle çifti:
# ['He travels to different countries frequently.', 'Frequent travel to different countries is a part of his job.']
# Similarity Score:0.8261736035346985
#
# 19. Cümle çifti:
# ['She creates amazing sculptures.', 'Creating amazing sculptures is her passion and profession.']
# Similarity Score:0.8911135792732239
#
# 20. Cümle çifti:
# ['We love exploring new cultures.', 'Exploring new cultures is a fascinating adventure for us.']
# Similarity Score:0.8776737451553345

# %% [markdown]
# # all-MiniLM-L12-v2
#
# 750k download
#
# 135mb

# %%
l12_v2 = SentenceTransformer('sentence-transformers/all-MiniLM-L12-v2')

# %%
l12_v2_list = []
for index, sentence_list in df.iterrows():
    score = l12_v2.get_similarity(sentence_list[0])
    print(f"{index}. Cümle çifti:\n{sentence_list[0]}\nSimilarity Score:{score}\n")
    l12_v2_list.append(score)
# Out:
# 1. Cümle çifti:
# ['I like to read books.', 'Reading books is something I enjoy.']
# Similarity Score:0.8832626342773438
#
# 2. Cümle çifti:
# ['She sings beautifully.', 'Her singing is absolutely gorgeous.']
# Similarity Score:0.8029991388320923
#
# 3. Cümle çifti:
# ['They love playing soccer.', 'Playing soccer is their passion.']
# Similarity Score:0.8185909986495972
#
# 4. Cümle çifti:
# ['He enjoys cooking new recipes.', 'Cooking new recipes is his favorite hobby.']
# Similarity Score:0.8520865440368652
#
# 5. Cümle çifti:
# ['My sister dances gracefully.', 'Her graceful dance moves always mesmerize the audience.']
# Similarity Score:0.6080156564712524
#
# 6. Cümle çifti:
# ['We often travel to new places.', 'Exploring new places is something we do frequently.']
# Similarity Score:0.7906659841537476
#
# 7. Cümle çifti:
# ['They speak multiple languages.', 'Being multilingual is one of their impressive abilities.']
# Similarity Score:0.6801633834838867
#
# 8. Cümle çifti:
# ['I swim in the ocean every summer.', 'Swimming in the ocean during the summer is a tradition for me.']
# Similarity Score:0.8159225583076477
#
# 9. Cümle çifti:
# ['He runs marathons regularly.', 'Running marathons is a part of his routine.']
# Similarity Score:0.886987566947937
#
# 10. Cümle çifti:
# ['She paints beautiful landscapes.', 'Creating beautiful landscapes through painting is her talent.']
# Similarity Score:0.867141604423523
#
# 11. Cümle çifti:
# ['We enjoy watching movies together.', 'Watching movies together is our favorite bonding activity.']
# Similarity Score:0.7766472101211548
#
# 12. Cümle çifti:
# ['They play musical instruments skillfully.', 'Playing musical instruments skillfully is their forte.']
# Similarity Score:0.8416557908058167
#
# 13. Cümle çifti:
# ['I practice yoga every morning.', 'Practicing yoga is a daily ritual for me.']
# Similarity Score:0.832818865776062
#
# 14. Cümle çifti:
# ['He writes insightful poems.', 'Writing insightful poems is his creative outlet.']
# Similarity Score:0.9195475578308105
#
# 15. Cümle çifti:
# ['She codes computer programs effectively.', 'Coding computer programs effectively is her expertise.']
# Similarity Score:0.884627103805542
#
# 16. Cümle çifti:
# ['They study diligently for their exams.', 'Studying diligently for exams is their key to success.']
# Similarity Score:0.8620554804801941
#
# 17. Cümle çifti:
# ['I enjoy hiking in the mountains.', 'Hiking in the mountains is a thrilling experience for me.']
# Similarity Score:0.8744615912437439
#
# 18. Cümle çifti:
# ['He travels to different countries frequently.', 'Frequent travel to different countries is a part of his job.']
# Similarity Score:0.8387329578399658
#
# 19. Cümle çifti:
# ['She creates amazing sculptures.', 'Creating amazing sculptures is her passion and profession.']
# Similarity Score:0.9063653945922852
#
# 20. Cümle çifti:
# ['We love exploring new cultures.', 'Exploring new cultures is a fascinating adventure for us.']
# Similarity Score:0.8419915437698364

# %% [markdown]
# # all-distilroberta-v1
#
# 480k
#
# 330mb

# %%
distilroberta_v1 = SentenceTransformer('sentence-transformers/all-distilroberta-v1')

# %%
distilroberta_v1_list = []
for index, sentence_list in df.iterrows():
    score = distilroberta_v1.get_similarity(sentence_list[0])
    print(f"{index}. Cümle çifti:\n{sentence_list[0]}\nSimilarity Score:{score}\n")
    distilroberta_v1_list.append(score)
# Out:
# 1. Cümle çifti:
# ['I like to read books.', 'Reading books is something I enjoy.']
# Similarity Score:0.8938465118408203
#
# 2. Cümle çifti:
# ['She sings beautifully.', 'Her singing is absolutely gorgeous.']
# Similarity Score:0.8335720896720886
#
# 3. Cümle çifti:
# ['They love playing soccer.', 'Playing soccer is their passion.']
# Similarity Score:0.8954027891159058
#
# 4. Cümle çifti:
# ['He enjoys cooking new recipes.', 'Cooking new recipes is his favorite hobby.']
# Similarity Score:0.9178121089935303
#
# 5. Cümle çifti:
# ['My sister dances gracefully.', 'Her graceful dance moves always mesmerize the audience.']
# Similarity Score:0.5578739643096924
#
# 6. Cümle çifti:
# ['We often travel to new places.', 'Exploring new places is something we do frequently.']
# Similarity Score:0.8188501596450806
#
# 7. Cümle çifti:
# ['They speak multiple languages.', 'Being multilingual is one of their impressive abilities.']
# Similarity Score:0.7171542048454285
#
# 8. Cümle çifti:
# ['I swim in the ocean every summer.', 'Swimming in the ocean during the summer is a tradition for me.']
# Similarity Score:0.7428273558616638
#
# 9. Cümle çifti:
# ['He runs marathons regularly.', 'Running marathons is a part of his routine.']
# Similarity Score:0.8719927072525024
#
# 10. Cümle çifti:
# ['She paints beautiful landscapes.', 'Creating beautiful landscapes through painting is her talent.']
# Similarity Score:0.887996256351471
#
# 11. Cümle çifti:
# ['We enjoy watching movies together.', 'Watching movies together is our favorite bonding activity.']
# Similarity Score:0.8599021434783936
#
# 12. Cümle çifti:
# ['They play musical instruments skillfully.', 'Playing musical instruments skillfully is their forte.']
# Similarity Score:0.8356095552444458
#
# 13. Cümle çifti:
# ['I practice yoga every morning.', 'Practicing yoga is a daily ritual for me.']
# Similarity Score:0.8661624193191528
#
# 14. Cümle çifti:
# ['He writes insightful poems.', 'Writing insightful poems is his creative outlet.']
# Similarity Score:0.8881939649581909
#
# 15. Cümle çifti:
# ['She codes computer programs effectively.', 'Coding computer programs effectively is her expertise.']
# Similarity Score:0.9124130606651306
#
# 16. Cümle çifti:
# ['They study diligently for their exams.', 'Studying diligently for exams is their key to success.']
# Similarity Score:0.8487852215766907
#
# 17. Cümle çifti:
# ['I enjoy hiking in the mountains.', 'Hiking in the mountains is a thrilling experience for me.']
# Similarity Score:0.8206519484519958
#
# 18. Cümle çifti:
# ['He travels to different countries frequently.', 'Frequent travel to different countries is a part of his job.']
# Similarity Score:0.8294554352760315
#
# 19. Cümle çifti:
# ['She creates amazing sculptures.', 'Creating amazing sculptures is her passion and profession.']
# Similarity Score:0.9035865068435669
#
# 20. Cümle çifti:
# ['We love exploring new cultures.', 'Exploring new cultures is a fascinating adventure for us.']
# Similarity Score:0.8869929313659668

# %% [markdown]
# ## Modellerin similarity score' ları

# %%
pd.set_option('display.max_colwidth', None)
df["all-MiniLM-L6-v2"] = l6_v2_list
df["all-MiniLM-L12-v2"] = l12_v2_list
df["all-mpnet-base-v2"] = mpnet_base_v2_list
df["all-distilroberta-v1"] = distilroberta_v1_list

# %%
df.head()
# Out:
#                                                                                  sentences  \
# 1                             [I like to read books., Reading books is something I enjoy.]
# 2                            [She sings beautifully., Her singing is absolutely gorgeous.]
# 3                            [They love playing soccer., Playing soccer is their passion.]
# 4             [He enjoys cooking new recipes., Cooking new recipes is his favorite hobby.]
# 5  [My sister dances gracefully., Her graceful dance moves always mesmerize the audience.]
#
#    all-MiniLM-L6-v2  all-MiniLM-L12-v2  all-mpnet-base-v2  \
# 1          0.844543           0.883263           0.857398
# 2          0.847846           0.802999           0.886647
# 3          0.808742           0.818591           0.819993
# 4          0.863199           0.852087           0.907231
# 5          0.640851           0.608016           0.615742
#
#    all-distilroberta-v1
# 1              0.893847
# 2              0.833572
# 3              0.895403
# 4              0.917812
# 5              0.557874
